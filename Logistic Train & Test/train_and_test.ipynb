# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadNihalImran/ML-projects/blob/main/Logistic%20Train%20%26%20Test/train_and_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
import matplotlib.pyplot as plt
plt.scatter(df['age'], df['bought_insurance'],color='red',marker='+')

# %%
#test and train
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.1,random_state=42)

# %%
x = df['age']
y = df['bought_insurance']

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 0, 1])

# %%
y_test
# Out:
# 8     1
# 13    0
# 9     1
# Name: bought_insurance, dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
model.predict_proba(x_test)
# Out:
# array([[0.04794177, 0.95205823],
#        [0.77002692, 0.22997308],
#        [0.05409225, 0.94590775]])

# %%
model.coef_
# Out:
# array([[0.12718492]])

# %%
model.intercept_
# Out:
# array([-4.89682585])

# %%
model = LogisticRegression()

X = df[['age']].values  # Ensure X is 2D
y = df['bought_insurance'].values  # Ensure y is 1D

model.fit(X, y)

# Generate ages for plotting the curve
age_range = np.linspace(df['age'].min(), df['age'].max(), 300).reshape(-1, 1)
predicted_probs = model.predict_proba(age_range)[:, 1]

# Plot the data points and logistic regression curve
plt.figure(figsize=(8, 6))
plt.scatter(df['age'], df['bought_insurance'], color='blue', label='Data Points', alpha=0.6)
plt.plot(age_range, predicted_probs, color='red', linewidth=2, label='Logistic Regression Curve')
plt.xlabel('Age')
plt.ylabel('Probability of Buying Insurance')
plt.title('Logistic Regression for Age vs Insurance Purchase')
plt.legend()
plt.grid(True)
plt.show()
